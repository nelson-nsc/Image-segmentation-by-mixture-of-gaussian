# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ##### Load Training Data

# %%
def load_data(imgs, gts):
    '''load rgb images and ground truths; and
    calculate the prior for the likelihood
    '''
    data_true = []
    data_false = []
    for img, gt in zip(imgs, gts):
        # load images
        image = plt.imread(img)
        image = image / 255
        # ground truth
        gtruth = (plt.imread(gt)[:,:,2]).astype(int) # only needs one channel
        for i in range(gtruth.shape[0]):
            for j in range(gtruth.shape[1]):
                if gtruth[i, j] == 1.0:
                    data_true.append(image[i,j])
                else:
                    data_false.append(image[i,j])
    # reshape the data to d x n
    data_true = np.asarray(data_true).T
    data_false = np.asarray(data_false).T
    # calculate the prior
    pixels = data_false.shape[1] + data_true.shape[1]
    prior = [data_true.shape[1]/ pixels, data_false.shape[1]/ pixels]
    print('data_true: {} ; data_false: {}'.format(data_true.shape, data_false.shape))
    return data_true, data_false, prior

# %%
img_train = [
        './apples/Apples_by_kightp_Pat_Knight_flickr.jpg',
        './apples/ApplesAndPears_by_srqpix_ClydeRobinson.jpg',
        './apples/bobbing-for-apples.jpg'
    ]

train_gt = [
        './apples/Apples_by_kightp_Pat_Knight_flickr.png',
        './apples/ApplesAndPears_by_srqpix_ClydeRobinson.png',
        './apples/bobbing-for-apples.png'
    ]
data_true, data_false, prior = load_data(img_train, train_gt)
# Out:
# data_true: (3, 424647) ; data_false: (3, 375653)

# %% [markdown]
# ##### Gaussian Probability

# %%
def gaussProb(data, mean, cov):
    """Calculate probability of observing data points under a gauss. distribution ~ [mean, cov]"""
    nDim ,nData = data.shape
    data = data - mean[:, None]
    sig = np.linalg.inv(cov)
    power = (data.T.dot(sig) * data.T).sum(1)
    prob = (np.linalg.det(2 * np.pi * cov)**-0.5) * np.exp(-0.5 * power)
    print('sig: {} ; data: {}, power: {}; prob: {}'.format(sig.shape, data.shape, power.shape, prob.shape))
    # mean = mean.reshape(nDim, 1)
    # cov = cov.reshape(nDim,nDim)
    # prob = ((2*np.pi)**(-nDim/2)*np.linalg.det(cov)**0.5)**-1 * np.exp(-0.5*(data-mean).T@np.linalg.inv(cov)@(data-mean))
    return prob

# %% [markdown]
# ##### Likelihood & Loglikelihood

# %%
def likelihood(data, model_estimate):
        """Calculate likelihood of seeing each pixel individually with our model estimate"""
        nDim, nData = data.shape
        logs = np.zeros((model_estimate['k'], nData))

        for current_c in range(model_estimate['k']):
            current_weight = model_estimate['weight'][current_c]
            current_mean = model_estimate['mean'][:, current_c]
            current_cov = model_estimate['cov'][:, :, current_c]
            logs[current_c, :] = current_weight * gaussProb(data, current_mean, current_cov)
        like = np.sum(logs, axis=0)
        # print("logs: {} ; likelihood: {}".format(logs.shape, like.shape))
        return like

# %%
def log_likelihood(data, model_estimate):
    """Calculate log likelihood of seeing the full image (all pixels) with our model estimate"""

    n_data = data.shape[1]
    logs = np.zeros((model_estimate['k'], n_data))

    for current_c in range(model_estimate['k']):
        current_weight = model_estimate['weight'][current_c]
        current_mean = model_estimate['mean'][:, current_c]
        current_cov = model_estimate['cov'][:, :, current_c]
        logs[current_c, :] = current_weight * gaussProb(data, current_mean, current_cov)

    # We want the likelihood of seeing all these pixels, and hence we add over k and all pixels,
    # not just k. Add not multiply due to log likelihood
    log_likelihood = np.sum(np.log(np.sum(logs, axis=0)))
    # print("logs: {} ; log likelihood: {}".format(logs.shape, log_likelihood.shape))
    return log_likelihood

# %% [markdown]
# ##### EM Algorithm

# %%
def fit_gaussian(data, k):
    nDim, nData = data.shape
    mean = np.mean(data, axis=1)
    #cov = 1 / nData * (data - mean.reshape(nDim,1)) @ (data - mean.reshape(nDim,1)).T
    cov = 1 / nData * (data - mean[:, None]) @ (data - mean[:, None]).T
    postHidden = np.zeros(shape=(k, nData))

    mixGaussEst = dict()
    mixGaussEst['d'] = nDim
    mixGaussEst['k'] = k
    # initialise parameters
    mixGaussEst['weight'] = (1 / k) * np.ones(shape=(k))
    mixGaussEst['mean'] = 2 * np.random.randn(nDim, k)
    mixGaussEst['cov'] = (1 + 0.2 * np.random.normal(size=(k)))[None, None] * cov[:, :, None]

    logLike = log_likelihood(data, mixGaussEst)
    print('Log Likelihood Iter 0 : {:4.3f}\n'.format(logLike))

    nIter = 10

    for cIter in range(nIter):
        ### Expectation step ###

        for i in range(k):
            weight = mixGaussEst['weight'][i]
            mean = mixGaussEst['mean'][:,i]
            cov = mixGaussEst['cov'][:,:,i]
            postHidden[i,:] = weight * gaussProb(data, mean, cov)
            postHidden /= np.sum(postHidden, axis=0) #+ sys.float_info.min # aviod singularity

        respon_k = np.sum(postHidden, axis=1)
        
        ### Maximization Step ###

        # for each constituent Gaussian
        for i in range(k):
            res = postHidden[i,:]
            mixGaussEst['weight'][i] = np.sum(res) / np.sum(postHidden)
            mixGaussEst['mean'][:,i] = (res*data).sum(1)/np.sum(res)
            mixGaussEst['cov'][:,:,i] = \
            ((((data - mixGaussEst['mean'][:, i][:, None])*res[None,:])@(data - mixGaussEst['mean'][:, i][:, None]).T)/respon_k[i])
            
        # calculate the log likelihood
        logLike = log_likelihood(data, mixGaussEst)
        print('Log Likelihood After Iter {} : {:4.3f}\n'.format(cIter, logLike))
    return mixGaussEst

# %%
def posterior(im_path, prior, data_true, data_false):
    # let's define priors for whether the pixel is skin or non skin
    prior_true, prior_false = prior
    # now run through the pixels in the image and classify them as being skin or
    im = plt.imread(im_path)
    imY, imX, imZ = im.shape
    like_true = likelihood(im.reshape(imY*imX,imZ).T, data_true).reshape(imY,imX)
    like_false = likelihood(im.reshape(imY*imX,imZ).T, data_false).reshape(imY,imX)
    # print(im.shape)
    posterior_true = like_true * prior_true / (like_true * prior_true + like_false * prior_false)
    # posterior_true_binary = (posterior_true > self._threshold).astype(int)
    plt.imshow(posterior_true)
    return posterior_true

# %%
data_true, data_false, prior = load_data(img_train, train_gt)
mixGassEst_true = fit_gaussian(data_true, 3)
mixGassEst_false = fit_gaussian(data_false, 3)
post = posterior(img_train[0], prior, mixGassEst_true, mixGassEst_false)
# Out:
# data_true: (3, 424647) ; data_false: (3, 375653)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# Log Likelihood Iter 0 : -27426497.208
#
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# Log Likelihood After Iter 0 : 284167.408
#
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# Log Likelihood After Iter 1 : 284167.408
#
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# Log Likelihood After Iter 2 : 284167.408
#
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# Log Likelihood After Iter 3 : 284167.408
#
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# Log Likelihood After Iter 4 : 284167.408
#
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# Log Likelihood After Iter 5 : 284167.408
#
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# Log Likelihood After Iter 6 : 284167.408
#
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# Log Likelihood After Iter 7 : 284167.408
#
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# Log Likelihood After Iter 8 : 284167.408
#
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# sig: (3, 3) ; data: (3, 424647), power: (424647,); prob: (424647,)
# Log Likelihood After Iter 9 : 284167.408
#
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# Log Likelihood Iter 0 : -56971191.686
#
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# Log Likelihood After Iter 0 : 413030.790
#
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# Log Likelihood After Iter 1 : 413030.790
#
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# Log Likelihood After Iter 2 : 413030.790
#
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# Log Likelihood After Iter 3 : 413030.790
#
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# Log Likelihood After Iter 4 : 413030.790
#
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# Log Likelihood After Iter 5 : 413030.790
#
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# Log Likelihood After Iter 6 : 413030.790
#
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# sig: (3, 3) ; data: (3, 375653), power: (375653,); prob: (375653,)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# g:\My Drive\20-29 Maths and Science\21 Uni material\21.05 UCL\COMP0137 Machine Vision\02_PracticalMixGauss\CW1.ipynb Cell 13 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> data_true, data_false, prior = load_data(img_train, train_gt)
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> mixGassEst_true = fit_gaussian(data_true, 3)
# ----> <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> mixGassEst_false = fit_gaussian(data_false, 3)
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> post = posterior(img_train[0], prior, mixGassEst_true, mixGassEst_false)
#
# g:\My Drive\20-29 Maths and Science\21 Uni material\21.05 UCL\COMP0137 Machine Vision\02_PracticalMixGauss\CW1.ipynb Cell 13 in fit_gaussian(data, k)
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=39'>40</a>         mixGaussEst['cov'][:,:,i] = \
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=40'>41</a>         ((((data - mixGaussEst['mean'][:, i][:, None])*res[None,:])@(data - mixGaussEst['mean'][:, i][:, None]).T)/respon_k[i])
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=42'>43</a>     # calculate the log likelihood
# ---> <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=43'>44</a>     logLike = log_likelihood(data, mixGaussEst)
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=44'>45</a>     print('Log Likelihood After Iter {} : {:4.3f}\n'.format(cIter, logLike))
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=45'>46</a> return mixGaussEst
#
# g:\My Drive\20-29 Maths and Science\21 Uni material\21.05 UCL\COMP0137 Machine Vision\02_PracticalMixGauss\CW1.ipynb Cell 13 in log_likelihood(data, model_estimate)
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=8'>9</a>     current_mean = model_estimate['mean'][:, current_c]
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=9'>10</a>     current_cov = model_estimate['cov'][:, :, current_c]
# ---> <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=10'>11</a>     logs[current_c, :] = current_weight * gaussProb(data, current_mean, current_cov)
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=12'>13</a> # We want the likelihood of seeing all these pixels, and hence we add over k and all pixels,
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=13'>14</a> # not just k. Add not multiply due to log likelihood
#      <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=14'>15</a> log_likelihood = np.sum(np.log(np.sum(logs, axis=0)))
#
# g:\My Drive\20-29 Maths and Science\21 Uni material\21.05 UCL\COMP0137 Machine Vision\02_PracticalMixGauss\CW1.ipynb Cell 13 in gaussProb(data, mean, cov)
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> nDim ,nData = data.shape
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> data = data - mean[:, None]
# ----> <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> sig = np.linalg.inv(cov)
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a> power = (data.T.dot(sig) * data.T).sum(1)
#       <a href='vscode-notebook-cell:/g%3A/My%20Drive/20-29%20Maths%20and%20Science/21%20Uni%20material/21.05%20UCL/COMP0137%20Machine%20Vision/02_PracticalMixGauss/CW1.ipynb#X23sZmlsZQ%3D%3D?line=6'>7</a> prob = (np.linalg.det(2 * np.pi * cov)**-0.5) * np.exp(-0.5 * power)
#
# File <__array_function__ internals>:180, in inv(*args, **kwargs)
#
# File c:\Users\singc\miniconda3\envs\MV-comp0137\lib\site-packages\numpy\linalg\linalg.py:552, in inv(a)
#     550 signature = 'D->D' if isComplexType(t) else 'd->d'
#     551 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 552 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     553 return wrap(ainv.astype(result_t, copy=False))
#
# File c:\Users\singc\miniconda3\envs\MV-comp0137\lib\site-packages\numpy\linalg\linalg.py:89, in _raise_linalgerror_singular(err, flag)
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix
